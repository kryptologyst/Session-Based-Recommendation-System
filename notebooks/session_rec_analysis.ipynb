# %% [markdown]
# # Session-Based Recommendation System
#
# This notebook demonstrates the session-based recommendation system with multiple models and evaluation metrics.

# %%
import sys
sys.path.append('src')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List, Dict

from session_rec.data import DataLoader, SessionDataGenerator
from session_rec.models import (
    PopularityModel,
    ItemKNNModel,
    GRU4RecModel,
    SASRecModel,
)
from session_rec.evaluation import Evaluator
from session_rec.utils import set_seed

# Set random seed for reproducibility
set_seed(42)

# Configure plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
